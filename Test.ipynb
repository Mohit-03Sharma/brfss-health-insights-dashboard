# %%
from data_prep import load_brfss, build_layerQ

df = load_brfss()
layerQ = build_layerQ(df)

print(df.shape)
print(layerQ.head())
# Out:
# (2758852, 27)
#                        Class              Topic  \
# 0  Chronic Health Indicators         Depression
# 1               Demographics                Age
# 2               Demographics  Disability status
# 3  Chronic Health Indicators               COPD
# 4  Chronic Health Indicators             Kidney
#
#                                             Question
# 0  Ever told you that you have a form of depression?
# 1                                  What is your age?
# 2  Are you blind or do you have serious difficult...
# 3                           Ever told you have COPD?
# 4                 Ever told you have kidney disease?
